# %% [markdown]
# 1. Data Exploration and Preprocessing

# %%
import pandas as pd
df=pd.read_csv("blogs.csv")
df
# Out:
#                                                    Data              Labels
# 0     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 1     Newsgroups: alt.atheism\nPath: cantaloupe.srv....         alt.atheism
# 2     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...         alt.atheism
# 3     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 4     Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...         alt.atheism
# ...                                                 ...                 ...
# 1995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...  talk.religion.misc
# 1996  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1997  Xref: cantaloupe.srv.cs.cmu.edu talk.origins:4...  talk.religion.misc
# 1998  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1999  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...  talk.religion.misc
#
# [2000 rows x 2 columns]

# %%
df.head()
# Out:
#                                                 Data       Labels
# 0  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...  alt.atheism
# 1  Newsgroups: alt.atheism\nPath: cantaloupe.srv....  alt.atheism
# 2  Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...  alt.atheism
# 3  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...  alt.atheism
# 4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...  alt.atheism

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %%
num_cols=df.shape[1]

# %%
for i in range(1,num_cols):
    df.iloc[:,i] = LE.fit_transform(df.iloc[:,i])

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    2000 non-null   object
#  1   Labels  2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
Y = df.iloc[:,0]
X = df.iloc[:,1:]

# %%
print(df.columns)
# Out:
# Index(['Data', 'Labels'], dtype='object')

# %%
Y = df.iloc[:, 0]
X = df.iloc[:, 1:]
Y.info()
Y.value_counts()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2000 entries, 0 to 1999
# Series name: Data
# Non-Null Count  Dtype
# --------------  -----
# 2000 non-null   object
# dtypes: object(1)
# memory usage: 15.8+ KB
# Data
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X.iloc[:,0].astype(str))
print(X_tfidf.shape)
# Out:
# (2000, 10)

# %% [markdown]
# 2. Naive Bayes Model for Text Classification

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_tfidf, Y, test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
Y_pred_train = model.predict(x_train)
Y_pred_test = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(y_train,Y_pred_train)
print("Training Accuracy score:", ac1.round(2))
ac2 = accuracy_score(y_test,Y_pred_test)
print("Test Accuracy score:", ac2.round(2))
# Out:
# Training Accuracy score: 0.01
# Test Accuracy score: 0.0

# %% [markdown]
# 3. Sentiment Analysis

# %%
training_acc = []
test_acc = []

# %%
from textblob import TextBlob

def get_sentiment(text):
  """
  Analyzes the sentiment of a given text and returns a string representing the sentiment ("positive", "negative", or "neutral").
  """
  analysis = TextBlob(text)
  polarity = analysis.sentiment.polarity
  if polarity > 0:
    return "positive"
  elif polarity < 0:
    return "negative"
  else:
    return "neutral"

df["Sentiment"] = df["Data"].apply(get_sentiment)
df.head()
# Out:
#                                                 Data Labels Sentiment
# 0  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...      0  positive
# 1  Newsgroups: alt.atheism\nPath: cantaloupe.srv....      0  negative
# 2  Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...      0  positive
# 3  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...      0  positive
# 4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...      0  positive

# %%
categories = ["News"] * 500 + ["Sports"] * 500 + ["Entertainment"] * 500 + ["Other"] * 500
df["Category"] = categories

sentiment_counts = df.groupby(["Category", "Sentiment"]).size().unstack()
print(sentiment_counts)
# Out:
# Sentiment      negative  positive
# Category
# Entertainment       128       372
# News                113       387
# Other               101       399
# Sports              115       385

# %% [markdown]
# 4. Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
y_train_pred = model.predict(x_train)
accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train = precision_score(y_train, y_train_pred, average="weighted")
recall_train = recall_score(y_train, y_train_pred, average="weighted")
f1_train = f1_score(y_train, y_train_pred, average="weighted")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test_pred = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_test_pred)
precision_test = precision_score(y_test, y_test_pred, average="weighted")
recall_test = recall_score(y_test, y_test_pred, average="weighted")
f1_test = f1_score(y_test, y_test_pred, average="weighted")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Training set performance:")
print("- Accuracy:", accuracy_train)
print("- Precision:", precision_train)
print("- Recall:", recall_train)
print("- F1-score:", f1_train)
# Out:
# Training set performance:
# - Accuracy: 0.00625
# - Precision: 7.044192029125015e-05
# - Recall: 0.00625
# - F1-score: 0.0001391725738321997

# %%
print("\nTest set performance:")
print("- Accuracy:", accuracy_train)
print("- Precision:", precision_train)
print("- Recall:", recall_train)
print("- F1-score:", f1_train)
# Out:
# Test set performance:
# - Accuracy: 0.00625
# - Precision: 7.044192029125015e-05
# - Recall: 0.00625
# - F1-score: 0.0001391725738321997

# %%
print("**Model Performance:**")
print("- Training Accuracy:", ac1.round(2))
print("- Test Accuracy:", ac2.round(2))
# Out:
# **Model Performance:**
# - Training Accuracy: 0.01
# - Test Accuracy: 0.0

# %%
print("\n**Challenges:**")
print("- Imbalanced dataset: The dataset contained varying numbers of samples for each category, which could affect the model's performance on minority classes.")
print("- Feature extraction: The TF-IDF vectorization might not have captured all the relevant information from the text data, potentially limiting the model's accuracy.")
print("- Model selection: The choice of the Naive Bayes classifier might not be optimal for this task, and exploring other algorithms could potentially improve performance.")
# Out:
# **Challenges:**
# - Imbalanced dataset: The dataset contained varying numbers of samples for each category, which could affect the model's performance on minority classes.
# - Feature extraction: The TF-IDF vectorization might not have captured all the relevant information from the text data, potentially limiting the model's accuracy.
# - Model selection: The choice of the Naive Bayes classifier might not be optimal for this task, and exploring other algorithms could potentially improve performance.

# %%
sentiment_percentages = sentiment_counts.apply(lambda x: x / x.sum(), axis=1)
print(sentiment_percentages)

if sentiment_percentages.loc["News", "positive"] > 0.6:
  print("The majority of news blog posts have a positive sentiment.")
else:
  print("The majority of news blog posts have a negative sentiment.")
# Out:
# Sentiment      negative  positive
# Category
# Entertainment     0.256     0.744
# News              0.226     0.774
# Other             0.202     0.798
# Sports            0.230     0.770
# The majority of news blog posts have a positive sentiment.
